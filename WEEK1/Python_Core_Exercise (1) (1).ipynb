# %%
#task 1.1
from datetime import datetime
import random

raw_sensor_data = []

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

for i in range(100):
    device_id = f"DEV{i+1:03}"

    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)
    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)
for reading in raw_sensor_data:
    print(reading)

#task1.2

temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == 'Temperature_Sensor':
        timestamp = reading[0]
        device_id = reading[1]
        location = reading[3]
        temperature = reading[4]

        temp_dict = {
            'timestamp': timestamp,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': temperature
        }

        temperature_readings.append(temp_dict)
for reading in temperature_readings:
  print(reading)

#task1.3

unique_locations = {reading[3] for reading in raw_sensor_data}
print(unique_locations)

#task1.4

device_stats = {}

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]
    if device_type not in device_stats:
        device_stats[device_type] = (value, value)
    else:
        current_min, current_max = device_stats[device_type]
        new_min = min(current_min, value)
        new_max = max(current_max, value)
        device_stats[device_type] = (new_min, new_max)

print(device_stats)

#task1.5.1

sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]
print(sliced_readings_2)

#task 1.5.2

sample_string = "Python Programming"
substring_1 = sample_string[7:19]
substring_2 = sample_string[5::-1]
print(substring_1)
print(substring_2)

#task 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]
print(fifth_reading_device_type)
print(device_type_suffix)

#task 2.1

def get_readings_by_location(readings_list, target_location):
  result = []

  for reading in readings_list:
    if reading[3] == target_location:
      result.append(reading)
  return(result)
filtered_readings = get_readings_by_location(raw_sensor_data, 'Lab1')
print(filtered_readings)

#task 2.2

def calculate_average_temperature(temp_data_list):
    total = 0
    count = 0

    for reading in temp_data_list:
        total += reading['temperature_celsius']
        count += 1

    if count == 0:
        return 0.0

    return total / count
avg_temp = calculate_average_temperature(temperature_readings)
print(avg_temp)

#task 2.3

def generate_report_line(reading_dict):
  return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

for reading in temperature_readings:
    print(generate_report_line(reading))

#task 3.1

import os
reports_dir = 'sensor_reports'

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")

#task 3.2

from datetime import datetime

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = '%Y-%m-%d %H:%M:%S'

    first_dt = datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days

    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"Duration: {days} days, {hours} hours, {minutes} minutes")

#task 3.3

import random

for i in range(5):
    num = random.randint(100, 200)
    print(num)

#task 4.1

import os

report_filename = os.path.join(reports_dir, 'temperature_report.txt')

try:
    with open(report_filename, 'w') as f:
        for reading in temperature_readings:
            f.write(generate_report_line(reading) + '\n')

    print(f"\nTemperature report written to '{report_filename}'.")

except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

#task 4.2

import os

report_filename = os.path.join('sensor_reports', 'temperature_report.txt')

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("First 3 lines from the report:")
    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"Error reading file '{report_filename}': {e}")
# Out:
# ('2026-07-21 05:41:36', 'DEV001', 'Pressure_Sensor', 'Lab1', 1025.74)
# ('2026-07-21 05:41:36', 'DEV002', 'Light_Sensor', 'Warehouse', 458.44)
# ('2026-07-21 05:41:36', 'DEV003', 'Humidity_Sensor', 'OfficeA', 79.04)
# ('2026-07-21 05:41:36', 'DEV004', 'Humidity_Sensor', 'OfficeA', 74.54)
# ('2026-07-21 05:41:36', 'DEV005', 'Pressure_Sensor', 'OfficeA', 993.0)
# ('2026-07-21 05:41:36', 'DEV006', 'Light_Sensor', 'Warehouse', 825.78)
# ('2026-07-21 05:41:36', 'DEV007', 'Humidity_Sensor', 'Lab1', 64.07)
# ('2026-07-21 05:41:36', 'DEV008', 'Temperature_Sensor', 'Warehouse', 18.84)
# ('2026-07-21 05:41:36', 'DEV009', 'Temperature_Sensor', 'Warehouse', 21.88)
# ('2026-07-21 05:41:36', 'DEV010', 'Pressure_Sensor', 'Lab1', 989.54)
# ('2026-07-21 05:41:36', 'DEV011', 'Temperature_Sensor', 'Lab2', 29.6)
# ('2026-07-21 05:41:36', 'DEV012', 'Pressure_Sensor', 'OfficeB', 1028.03)
# ('2026-07-21 05:41:36', 'DEV013', 'Light_Sensor', 'Warehouse', 917.07)
# ('2026-07-21 05:41:36', 'DEV014', 'Light_Sensor', 'Lab2', 623.7)
# ('2026-07-21 05:41:36', 'DEV015', 'Temperature_Sensor', 'OfficeA', 28.12)
# ('2026-07-21 05:41:36', 'DEV016', 'Temperature_Sensor', 'Lab1', 21.08)
# ('2026-07-21 05:41:36', 'DEV017', 'Temperature_Sensor', 'OfficeA', 25.66)
# ('2026-07-21 05:41:36', 'DEV018', 'Light_Sensor', 'OfficeA', 164.95)
# ('2026-07-21 05:41:36', 'DEV019', 'Light_Sensor', 'OfficeA', 669.88)
# ('2026-07-21 05:41:36', 'DEV020', 'Light_Sensor', 'Warehouse', 588.76)
# ('2026-07-21 05:41:36', 'DEV021', 'Light_Sensor', 'Lab2', 612.72)
# ('2026-07-21 05:41:36', 'DEV022', 'Humidity_Sensor', 'OfficeB', 45.02)
# ('2026-07-21 05:41:36', 'DEV023', 'Humidity_Sensor', 'Warehouse', 53.93)
# ('2026-07-21 05:41:36', 'DEV024', 'Pressure_Sensor', 'Warehouse', 1010.76)
# ('2026-07-21 05:41:36', 'DEV025', 'Humidity_Sensor', 'OfficeB', 54.68)
# ('2026-07-21 05:41:36', 'DEV026', 'Humidity_Sensor', 'Warehouse', 31.36)
# ('2026-07-21 05:41:36', 'DEV027', 'Light_Sensor', 'OfficeA', 331.5)
# ('2026-07-21 05:41:36', 'DEV028', 'Pressure_Sensor', 'OfficeB', 1018.37)
# ('2026-07-21 05:41:36', 'DEV029', 'Humidity_Sensor', 'Warehouse', 32.42)
# ('2026-07-21 05:41:36', 'DEV030', 'Pressure_Sensor', 'OfficeA', 1001.63)
# ('2026-07-21 05:41:36', 'DEV031', 'Humidity_Sensor', 'OfficeA', 70.99)
# ('2026-07-21 05:41:36', 'DEV032', 'Light_Sensor', 'Warehouse', 512.98)
# ('2026-07-21 05:41:36', 'DEV033', 'Temperature_Sensor', 'OfficeB', 25.53)
# ('2026-07-21 05:41:36', 'DEV034', 'Humidity_Sensor', 'Warehouse', 50.57)
# ('2026-07-21 05:41:36', 'DEV035', 'Pressure_Sensor', 'Lab2', 1024.1)
# ('2026-07-21 05:41:36', 'DEV036', 'Pressure_Sensor', 'OfficeA', 1022.17)
# ('2026-07-21 05:41:36', 'DEV037', 'Pressure_Sensor', 'Lab1', 991.02)
# ('2026-07-21 05:41:36', 'DEV038', 'Humidity_Sensor', 'Warehouse', 71.74)
# ('2026-07-21 05:41:36', 'DEV039', 'Temperature_Sensor', 'OfficeA', 25.34)
# ('2026-07-21 05:41:36', 'DEV040', 'Light_Sensor', 'OfficeB', 967.35)
# ('2026-07-21 05:41:36', 'DEV041', 'Temperature_Sensor', 'Warehouse', 26.86)
# ('2026-07-21 05:41:36', 'DEV042', 'Light_Sensor', 'Warehouse', 496.93)
# ('2026-07-21 05:41:36', 'DEV043', 'Pressure_Sensor', 'OfficeA', 983.84)
# ('2026-07-21 05:41:36', 'DEV044', 'Light_Sensor', 'OfficeA', 730.43)
# ('2026-07-21 05:41:36', 'DEV045', 'Temperature_Sensor', 'Lab1', 21.79)
# ('2026-07-21 05:41:36', 'DEV046', 'Humidity_Sensor', 'Lab1', 38.39)
# ('2026-07-21 05:41:36', 'DEV047', 'Humidity_Sensor', 'Lab2', 65.26)
# ('2026-07-21 05:41:36', 'DEV048', 'Humidity_Sensor', 'OfficeA', 78.94)
# ('2026-07-21 05:41:36', 'DEV049', 'Temperature_Sensor', 'OfficeA', 29.31)
# ('2026-07-21 05:41:36', 'DEV050', 'Pressure_Sensor', 'Lab1', 984.42)
# ('2026-07-21 05:41:36', 'DEV051', 'Light_Sensor', 'OfficeB', 169.6)
# ('2026-07-21 05:41:36', 'DEV052', 'Temperature_Sensor', 'OfficeA', 21.67)
# ('2026-07-21 05:41:36', 'DEV053', 'Light_Sensor', 'Lab1', 171.26)
# ('2026-07-21 05:41:36', 'DEV054', 'Temperature_Sensor', 'Warehouse', 22.51)
# ('2026-07-21 05:41:36', 'DEV055', 'Pressure_Sensor', 'Warehouse', 997.02)
# ('2026-07-21 05:41:36', 'DEV056', 'Pressure_Sensor', 'Lab2', 999.01)
# ('2026-07-21 05:41:36', 'DEV057', 'Humidity_Sensor', 'OfficeB', 58.44)
# ('2026-07-21 05:41:36', 'DEV058', 'Pressure_Sensor', 'OfficeB', 984.17)
# ('2026-07-21 05:41:36', 'DEV059', 'Humidity_Sensor', 'OfficeB', 69.59)
# ('2026-07-21 05:41:36', 'DEV060', 'Pressure_Sensor', 'Lab2', 990.54)
# ('2026-07-21 05:41:36', 'DEV061', 'Pressure_Sensor', 'OfficeA', 1029.36)
# ('2026-07-21 05:41:36', 'DEV062', 'Pressure_Sensor', 'Warehouse', 987.37)
# ('2026-07-21 05:41:36', 'DEV063', 'Temperature_Sensor', 'OfficeB', 27.36)
# ('2026-07-21 05:41:36', 'DEV064', 'Light_Sensor', 'Warehouse', 379.58)
# ('2026-07-21 05:41:36', 'DEV065', 'Temperature_Sensor', 'Lab1', 24.92)
# ('2026-07-21 05:41:36', 'DEV066', 'Light_Sensor', 'OfficeB', 333.41)
# ('2026-07-21 05:41:36', 'DEV067', 'Pressure_Sensor', 'OfficeA', 1001.66)
# ('2026-07-21 05:41:36', 'DEV068', 'Pressure_Sensor', 'OfficeA', 981.57)
# ('2026-07-21 05:41:36', 'DEV069', 'Pressure_Sensor', 'OfficeB', 994.28)
# ('2026-07-21 05:41:36', 'DEV070', 'Humidity_Sensor', 'Lab2', 43.43)
# ('2026-07-21 05:41:36', 'DEV071', 'Humidity_Sensor', 'OfficeB', 49.55)
# ('2026-07-21 05:41:36', 'DEV072', 'Humidity_Sensor', 'Lab2', 70.13)
# ('2026-07-21 05:41:36', 'DEV073', 'Pressure_Sensor', 'OfficeA', 1003.3)
# ('2026-07-21 05:41:36', 'DEV074', 'Pressure_Sensor', 'OfficeB', 991.34)
# ('2026-07-21 05:41:36', 'DEV075', 'Humidity_Sensor', 'Lab1', 65.69)
# ('2026-07-21 05:41:36', 'DEV076', 'Humidity_Sensor', 'Lab1', 79.36)
# ('2026-07-21 05:41:36', 'DEV077', 'Light_Sensor', 'Lab1', 454.94)
# ('2026-07-21 05:41:36', 'DEV078', 'Pressure_Sensor', 'Lab1', 1025.98)
# ('2026-07-21 05:41:36', 'DEV079', 'Light_Sensor', 'Warehouse', 794.64)
# ('2026-07-21 05:41:36', 'DEV080', 'Light_Sensor', 'OfficeB', 691.4)
# ('2026-07-21 05:41:36', 'DEV081', 'Light_Sensor', 'OfficeA', 691.92)
# ('2026-07-21 05:41:36', 'DEV082', 'Pressure_Sensor', 'Warehouse', 1029.9)
# ('2026-07-21 05:41:36', 'DEV083', 'Light_Sensor', 'Lab2', 749.15)
# ('2026-07-21 05:41:36', 'DEV084', 'Pressure_Sensor', 'Lab1', 1013.89)
# ('2026-07-21 05:41:36', 'DEV085', 'Humidity_Sensor', 'OfficeB', 61.16)
# ('2026-07-21 05:41:36', 'DEV086', 'Light_Sensor', 'Warehouse', 192.42)
# ('2026-07-21 05:41:36', 'DEV087', 'Light_Sensor', 'Warehouse', 691.18)
# ('2026-07-21 05:41:36', 'DEV088', 'Light_Sensor', 'Lab2', 367.42)
# ('2026-07-21 05:41:36', 'DEV089', 'Pressure_Sensor', 'OfficeA', 996.33)
# ('2026-07-21 05:41:36', 'DEV090', 'Temperature_Sensor', 'OfficeB', 20.18)
# ('2026-07-21 05:41:36', 'DEV091', 'Humidity_Sensor', 'Warehouse', 60.42)
# ('2026-07-21 05:41:36', 'DEV092', 'Humidity_Sensor', 'OfficeB', 71.12)
# ('2026-07-21 05:41:36', 'DEV093', 'Pressure_Sensor', 'Lab1', 1016.81)
# ('2026-07-21 05:41:36', 'DEV094', 'Light_Sensor', 'OfficeB', 870.4)
# ('2026-07-21 05:41:36', 'DEV095', 'Temperature_Sensor', 'Warehouse', 26.58)
# ('2026-07-21 05:41:36', 'DEV096', 'Light_Sensor', 'Lab1', 640.94)
# ('2026-07-21 05:41:36', 'DEV097', 'Temperature_Sensor', 'Lab1', 21.5)
# ('2026-07-21 05:41:36', 'DEV098', 'Light_Sensor', 'OfficeB', 834.71)
# ('2026-07-21 05:41:36', 'DEV099', 'Humidity_Sensor', 'Lab1', 53.3)
# ('2026-07-21 05:41:36', 'DEV100', 'Humidity_Sensor', 'Lab1', 52.01)
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV008', 'location': 'Warehouse', 'temperature_celsius': 18.84}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV009', 'location': 'Warehouse', 'temperature_celsius': 21.88}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV011', 'location': 'Lab2', 'temperature_celsius': 29.6}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV015', 'location': 'OfficeA', 'temperature_celsius': 28.12}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV016', 'location': 'Lab1', 'temperature_celsius': 21.08}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV017', 'location': 'OfficeA', 'temperature_celsius': 25.66}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV033', 'location': 'OfficeB', 'temperature_celsius': 25.53}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV039', 'location': 'OfficeA', 'temperature_celsius': 25.34}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV041', 'location': 'Warehouse', 'temperature_celsius': 26.86}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV045', 'location': 'Lab1', 'temperature_celsius': 21.79}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV049', 'location': 'OfficeA', 'temperature_celsius': 29.31}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV052', 'location': 'OfficeA', 'temperature_celsius': 21.67}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV054', 'location': 'Warehouse', 'temperature_celsius': 22.51}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV063', 'location': 'OfficeB', 'temperature_celsius': 27.36}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV065', 'location': 'Lab1', 'temperature_celsius': 24.92}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV090', 'location': 'OfficeB', 'temperature_celsius': 20.18}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV095', 'location': 'Warehouse', 'temperature_celsius': 26.58}
# {'timestamp': '2026-07-21 05:41:36', 'device_id': 'DEV097', 'location': 'Lab1', 'temperature_celsius': 21.5}
# {'Lab1', 'OfficeB', 'Warehouse', 'Lab2', 'OfficeA'}
# {'Pressure_Sensor': (981.57, 1029.9), 'Light_Sensor': (164.95, 967.35), 'Humidity_Sensor': (31.36, 79.36), 'Temperature_Sensor': (18.84, 29.6)}
# [('2026-07-21 05:41:36', 'DEV001', 'Pressure_Sensor', 'Lab1', 1025.74), ('2026-07-21 05:41:36', 'DEV006', 'Light_Sensor', 'Warehouse', 825.78), ('2026-07-21 05:41:36', 'DEV011', 'Temperature_Sensor', 'Lab2', 29.6), ('2026-07-21 05:41:36', 'DEV016', 'Temperature_Sensor', 'Lab1', 21.08), ('2026-07-21 05:41:36', 'DEV021', 'Light_Sensor', 'Lab2', 612.72), ('2026-07-21 05:41:36', 'DEV026', 'Humidity_Sensor', 'Warehouse', 31.36), ('2026-07-21 05:41:36', 'DEV031', 'Humidity_Sensor', 'OfficeA', 70.99), ('2026-07-21 05:41:36', 'DEV036', 'Pressure_Sensor', 'OfficeA', 1022.17), ('2026-07-21 05:41:36', 'DEV041', 'Temperature_Sensor', 'Warehouse', 26.86), ('2026-07-21 05:41:36', 'DEV046', 'Humidity_Sensor', 'Lab1', 38.39), ('2026-07-21 05:41:36', 'DEV051', 'Light_Sensor', 'OfficeB', 169.6), ('2026-07-21 05:41:36', 'DEV056', 'Pressure_Sensor', 'Lab2', 999.01), ('2026-07-21 05:41:36', 'DEV061', 'Pressure_Sensor', 'OfficeA', 1029.36), ('2026-07-21 05:41:36', 'DEV066', 'Light_Sensor', 'OfficeB', 333.41), ('2026-07-21 05:41:36', 'DEV071', 'Humidity_Sensor', 'OfficeB', 49.55), ('2026-07-21 05:41:36', 'DEV076', 'Humidity_Sensor', 'Lab1', 79.36), ('2026-07-21 05:41:36', 'DEV081', 'Light_Sensor', 'OfficeA', 691.92), ('2026-07-21 05:41:36', 'DEV086', 'Light_Sensor', 'Warehouse', 192.42), ('2026-07-21 05:41:36', 'DEV091', 'Humidity_Sensor', 'Warehouse', 60.42), ('2026-07-21 05:41:36', 'DEV096', 'Light_Sensor', 'Lab1', 640.94)]
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
# [('2026-07-21 05:41:36', 'DEV001', 'Pressure_Sensor', 'Lab1', 1025.74), ('2026-07-21 05:41:36', 'DEV007', 'Humidity_Sensor', 'Lab1', 64.07), ('2026-07-21 05:41:36', 'DEV010', 'Pressure_Sensor', 'Lab1', 989.54), ('2026-07-21 05:41:36', 'DEV016', 'Temperature_Sensor', 'Lab1', 21.08), ('2026-07-21 05:41:36', 'DEV037', 'Pressure_Sensor', 'Lab1', 991.02), ('2026-07-21 05:41:36', 'DEV045', 'Temperature_Sensor', 'Lab1', 21.79), ('2026-07-21 05:41:36', 'DEV046', 'Humidity_Sensor', 'Lab1', 38.39), ('2026-07-21 05:41:36', 'DEV050', 'Pressure_Sensor', 'Lab1', 984.42), ('2026-07-21 05:41:36', 'DEV053', 'Light_Sensor', 'Lab1', 171.26), ('2026-07-21 05:41:36', 'DEV065', 'Temperature_Sensor', 'Lab1', 24.92), ('2026-07-21 05:41:36', 'DEV075', 'Humidity_Sensor', 'Lab1', 65.69), ('2026-07-21 05:41:36', 'DEV076', 'Humidity_Sensor', 'Lab1', 79.36), ('2026-07-21 05:41:36', 'DEV077', 'Light_Sensor', 'Lab1', 454.94), ('2026-07-21 05:41:36', 'DEV078', 'Pressure_Sensor', 'Lab1', 1025.98), ('2026-07-21 05:41:36', 'DEV084', 'Pressure_Sensor', 'Lab1', 1013.89), ('2026-07-21 05:41:36', 'DEV093', 'Pressure_Sensor', 'Lab1', 1016.81), ('2026-07-21 05:41:36', 'DEV096', 'Light_Sensor', 'Lab1', 640.94), ('2026-07-21 05:41:36', 'DEV097', 'Temperature_Sensor', 'Lab1', 21.5), ('2026-07-21 05:41:36', 'DEV099', 'Humidity_Sensor', 'Lab1', 53.3), ('2026-07-21 05:41:36', 'DEV100', 'Humidity_Sensor', 'Lab1', 52.01)]
# 24.37388888888889
# [2026-07-21 05:41:36] Device DEV008 at Warehouse: 18.84°C
# [2026-07-21 05:41:36] Device DEV009 at Warehouse: 21.88°C
# [2026-07-21 05:41:36] Device DEV011 at Lab2: 29.6°C
# [2026-07-21 05:41:36] Device DEV015 at OfficeA: 28.12°C
# [2026-07-21 05:41:36] Device DEV016 at Lab1: 21.08°C
# [2026-07-21 05:41:36] Device DEV017 at OfficeA: 25.66°C
# [2026-07-21 05:41:36] Device DEV033 at OfficeB: 25.53°C
# [2026-07-21 05:41:36] Device DEV039 at OfficeA: 25.34°C
# [2026-07-21 05:41:36] Device DEV041 at Warehouse: 26.86°C
# [2026-07-21 05:41:36] Device DEV045 at Lab1: 21.79°C
# [2026-07-21 05:41:36] Device DEV049 at OfficeA: 29.31°C
# [2026-07-21 05:41:36] Device DEV052 at OfficeA: 21.67°C
# [2026-07-21 05:41:36] Device DEV054 at Warehouse: 22.51°C
# [2026-07-21 05:41:36] Device DEV063 at OfficeB: 27.36°C
# [2026-07-21 05:41:36] Device DEV065 at Lab1: 24.92°C
# [2026-07-21 05:41:36] Device DEV090 at OfficeB: 20.18°C
# [2026-07-21 05:41:36] Device DEV095 at Warehouse: 26.58°C
# [2026-07-21 05:41:36] Device DEV097 at Lab1: 21.5°C
#
# Directory 'sensor_reports' created.
# Duration: 0 days, 0 hours, 0 minutes
# 119
# 188
# 170
# 147
# 175
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
# First 3 lines from the report:
# [2026-07-21 05:41:36] Device DEV008 at Warehouse: 18.84°C
# [2026-07-21 05:41:36] Device DEV009 at Warehouse: 21.88°C
# [2026-07-21 05:41:36] Device DEV011 at Lab2: 29.6°C
